# %%
# Installing required packages
#install.packages("", lib="")
#remove.packages("", lib="")

# %%
# Libraries
library(anytime)
library(xts)
library(corrplot)
library(dplyr)
library(MASS)    # Library for backward and forward methods
library(car)     # For multicolinearity
library(dotenv)
library(lme4)    # For GLMM
library(pROC)

# %%
# Load paths
#setwd('..')
load_dot_env()
trends_path <- Sys.getenv("GOOGLE_TRENDS")
crypto_path <- Sys.getenv("CRYPTO")
data_path <- Sys.getenv("DATA_PATH")
my_root <- Sys.getenv("MY_ROOT")

# %% [markdown]
# # Loading data base

# %%
setwd(data_path)

# The database contains returns of btc price and google trends info.
db <- read.table("data_base.csv", sep=",", header = TRUE)

# %% [markdown]
# # Setting up

# %% [markdown]
# >**A logistic model will be built**
#
#
# - Two qualitatives variables ared added
# - The answer-y variable needs to be defined
# - Null model
# - Full model
# - Variables selection

# %%
# Two more variables will be created for identenfying the day hour and week day.
db$date <- as.POSIXct(db$date, format = "%Y-%m-%d %H:%M:%OS")

db$day <- as.factor(weekdays(db$date))
db$hour <- as.factor(as.numeric(strftime(db$date, format="%H")))

# %%
r_a <- -0.515865739661981
r_b <- 0.515830425509656



divide_y <- function(x){
    if(x < r_a){
        return(1)
    } else{
        return(0)
    }
}

db$y <- sapply(db$returns, divide_y)

# %%
sum(db$y)/dim(db)[1] #Percentage of 1's inside y-variable
# Out:
# [1] 0.1493778

# %% [markdown]
# >**At 0_explore_btc_prices.ipynb file we adjusted a curved to returns data, this was made for spliting the data in relatively equals parts. In this case the data was splited in 33.33%, 33.33% and 33.33% for the dicotomic y-variable**

# %% [markdown]
# >**We must say, the spliting is just an arbitray selection, it could've been for example 5%, 90% and 5%**

# %%
# Spliting the data into training and testing parts:
percent <- 0.8

db_training_t <- db[1:round(dim(db)[1]*percent, 0), ]
db_testing_t <- db[(round(dim(db)[1]*percent, 0)+1):dim(db)[1], ]

db_training <- subset(db_training_t, select=-c(date, returns, day, hour))
db_testing <- subset(db_testing_t, select=-c(date, returns, day, hour))

# %% [markdown]
# # Variable selection

# %%
mod_null <- glm(y ~ 1, data = db_training, family = "binomial")
mod_full <- glm(y ~ ., data = db_training, family = "binomial")

# %%
# The method Backward will be used for the selection of variables
mod_back <- stepAIC(mod_full, trace=TRUE, direction="backward")
# Out:
# Start:  AIC=16691.59
# y ~ altcoins.season + banking.system + bce + bill.gates + bitcoin.alert +
#     bitcoin.bubble + bitcoin.dump + bitcoin.hack + bitcoin.pump +
#     bitcoin.whales + bitcoin + blockchain + coindesk + coingecko +
#     coinmarketcap + cointelegraph + crypto.assets + cryptonews +
#     debt.jubilee + debt + derivatives.market + dollar + economic.collapse +
#     economic.stimulus + economy.recovery + elon.musk + financial.bubble +
#     financial.independence + housing.market + jamie.dimon + jerome.powell +
#     microsoft + money.printing + ray.dalio + real.economy + real.estate +
#     repo.market + satoshi.nakamoto + stimulus.bill + stocks.bubble +
#     stocks.crash + vitalik.buterin + volatility + warren.buffett +
#     wonder.woman + amazon + apple + bitcoin.twitter + ethereum +
#     smart.contracts + twitter + litecoin + ripple + netflix +
#     sec + investing + bloomberg + china.economy + facebook +
#     fed + financial.crisis
#
#                          Df Deviance   AIC
# - economy.recovery        1    16568 16690
# - elon.musk               1    16568 16690
# - financial.crisis        1    16568 16690
# - stocks.bubble           1    16568 16690
# - money.printing          1    16568 16690
# - china.economy           1    16568 16690
# - coinmarketcap           1    16568 16690
# - repo.market             1    16568 16690
# - litecoin                1    16568 16690
# - warren.buffett          1    16568 16690
# - wonder.woman            1    16568 16690
# - stocks.crash            1    16568 16690
# - jamie.dimon             1    16568 16690
# - cointelegraph           1    16568 16690
# - economic.collapse       1    16568 16690
# - financial.bubble        1    16568 16690
# - altcoins.season         1    16568 16690
# - coindesk                1    16569 16691
# - stimulus.bill           1    16569 16691
# - investing               1    16569 16691
# - twitter                 1    16569 16691
# - crypto.assets           1    16569 16691
# - dollar                  1    16569 16691
# - derivatives.market      1    16569 16691
# - apple                   1    16569 16691
# - bitcoin.pump            1    16570 16692
# <none>                         16568 16692
# - economic.stimulus       1    16570 16692
# - ripple                  1    16570 16692
# - bloomberg               1    16570 16692
# - debt                    1    16570 16692
# - netflix                 1    16570 16692
# - bill.gates              1    16571 16693
# - satoshi.nakamoto        1    16571 16693
# - financial.independence  1    16571 16693
# - real.estate             1    16571 16693
# - jerome.powell           1    16572 16694
# - smart.contracts         1    16572 16694
# - housing.market          1    16572 16694
# - coingecko               1    16572 16694
# - facebook                1    16573 16695
# - volatility              1    16575 16697
# - bce                     1    16576 16698
# - sec                     1    16576 16698
# - banking.system          1    16576 16698
# - real.economy            1    16577 16699
# - debt.jubilee            1    16578 16700
# - ethereum                1    16578 16700
# - fed                     1    16581 16703
# - blockchain              1    16582 16704
# - cryptonews              1    16584 16706
# - bitcoin.hack            1    16585 16707
# - bitcoin.bubble          1    16586 16708
# - vitalik.buterin         1    16587 16709
# - bitcoin.twitter         1    16590 16712
# - bitcoin.whales          1    16596 16718
# - microsoft               1    16596 16718
# - amazon                  1    16598 16720
# - bitcoin.dump            1    16602 16724
# - ray.dalio               1    16604 16726
# - bitcoin                 1    16615 16737
# - bitcoin.alert           1    16634 16756
#
# Step:  AIC=16689.59
# y ~ altcoins.season + banking.system + bce + bill.gates + bitcoin.alert +
#     bitcoin.bubble + bitcoin.dump + bitcoin.hack + bitcoin.pump +
#     bitcoin.whales + bitcoin + blockchain + coindesk + coingecko +
#     coinmarketcap + cointelegraph + crypto.assets + cryptonews +
#     debt.jubilee + debt + derivatives.market + dollar + economic.collapse +
#     economic.stimulus + elon.musk + financial.bubble + financial.independence +
#     housing.market + jamie.dimon + jerome.powell + microsoft +
#     money.printing + ray.dalio + real.economy + real.estate +
#     repo.market + satoshi.nakamoto + stimulus.bill + stocks.bubble +
#     stocks.crash + vitalik.buterin + volatility + warren.buffett +
#     wonder.woman + amazon + apple + bitcoin.twitter + ethereum +
#     smart.contracts + twitter + litecoin + ripple + netflix +
#     sec + investing + bloomberg + china.economy + facebook +
#     fed + financial.crisis
#
#                          Df Deviance   AIC
# - elon.musk               1    16568 16688
# - financial.crisis        1    16568 16688
# - stocks.bubble           1    16568 16688
# - money.printing          1    16568 16688
# - china.economy           1    16568 16688
# - coinmarketcap           1    16568 16688
# - repo.market             1    16568 16688
# - litecoin                1    16568 16688
# - warren.buffett          1    16568 16688
# - wonder.woman            1    16568 16688
# - stocks.crash            1    16568 16688
# - jamie.dimon             1    16568 16688
# - cointelegraph           1    16568 16688
# - economic.collapse       1    16568 16688
# - financial.bubble        1    16568 16688
# - altcoins.season         1    16568 16688
# - coindesk                1    16569 16689
# - stimulus.bill           1    16569 16689
# - investing               1    16569 16689
# - twitter                 1    16569 16689
# - crypto.assets           1    16569 16689
# - dollar                  1    16569 16689
# - derivatives.market      1    16569 16689
# - apple                   1    16569 16689
# - bitcoin.pump            1    16570 16690
# <none>                         16568 16690
# - economic.stimulus       1    16570 16690
# - ripple                  1    16570 16690
# - bloomberg               1    16570 16690
# - debt                    1    16570 16690
# - netflix                 1    16570 16690
# - bill.gates              1    16571 16691
# - satoshi.nakamoto        1    16571 16691
# - financial.independence  1    16571 16691
# - real.estate             1    16571 16691
# - jerome.powell           1    16572 16692
# - smart.contracts         1    16572 16692
# - housing.market          1    16572 16692
# - coingecko               1    16572 16692
# - facebook                1    16573 16693
# - volatility              1    16575 16695
# - bce                     1    16576 16696
# - sec                     1    16576 16696
# - banking.system          1    16576 16696
# - real.economy            1    16577 16697
# - debt.jubilee            1    16578 16698
# - ethereum                1    16578 16698
# - fed                     1    16581 16701
# - blockchain              1    16582 16702
# - cryptonews              1    16584 16704
# - bitcoin.hack            1    16585 16705
# - bitcoin.bubble          1    16586 16706
# - vitalik.buterin         1    16587 16707
# - bitcoin.twitter         1    16590 16710
# - bitcoin.whales          1    16596 16716
# - microsoft               1    16596 16716
# - amazon                  1    16598 16718
# - bitcoin.dump            1    16602 16722
# - ray.dalio               1    16604 16724
# - bitcoin                 1    16615 16735
# - bitcoin.alert           1    16634 16754
#
# Step:  AIC=16687.6
# y ~ altcoins.season + banking.system + bce + bill.gates + bitcoin.alert +
#     bitcoin.bubble + bitcoin.dump + bitcoin.hack + bitcoin.pump +
#     bitcoin.whales + bitcoin + blockchain + coindesk + coingecko +
#     coinmarketcap + cointelegraph + crypto.assets + cryptonews +
#     debt.jubilee + debt + derivatives.market + dollar + economic.collapse +
#     economic.stimulus + financial.bubble + financial.independence +
#     housing.market + jamie.dimon + jerome.powell + microsoft +
#     money.printing + ray.dalio + real.economy + real.estate +
#     repo.market + satoshi.nakamoto + stimulus.bill + stocks.bubble +
#     stocks.crash + vitalik.buterin + volatility + warren.buffett +
#     wonder.woman + amazon + apple + bitcoin.twitter + ethereum +
#     smart.contracts + twitter + litecoin + ripple + netflix +
#     sec + investing + bloomberg + china.economy + facebook +
#     fed + financial.crisis
#                          Df Deviance   AIC
# - financial.crisis        1    16568 16686
# - stocks.bubble           1    16568 16686
# - money.printing          1    16568 16686
# - china.economy           1    16568 16686
# - coinmarketcap           1    16568 16686
# - repo.market             1    16568 16686
# - litecoin                1    16568 16686
# - warren.buffett          1    16568 16686
# - wonder.woman            1    16568 16686
# - stocks.crash            1    16568 16686
# - jamie.dimon             1    16568 16686
# - cointelegraph           1    16568 16686
# - economic.collapse       1    16568 16686
# - financial.bubble        1    16568 16686
# - altcoins.season         1    16568 16686
# - coindesk                1    16569 16687
# - stimulus.bill           1    16569 16687
# - investing               1    16569 16687
# - twitter                 1    16569 16687
# - crypto.assets           1    16569 16687
# - dollar                  1    16569 16687
# - derivatives.market      1    16569 16687
# - apple                   1    16569 16687
# - bitcoin.pump            1    16570 16688
# <none>                         16568 16688
# - economic.stimulus       1    16570 16688
# - bloomberg               1    16570 16688
# - ripple                  1    16570 16688
# - debt                    1    16570 16688
# - netflix                 1    16570 16688
# - bill.gates              1    16571 16689
# - satoshi.nakamoto        1    16571 16689
# - financial.independence  1    16571 16689
# - real.estate             1    16571 16689
# - jerome.powell           1    16572 16690
# - smart.contracts         1    16572 16690
# - housing.market          1    16572 16690
# - coingecko               1    16572 16690
# - facebook                1    16573 16691
# - volatility              1    16575 16693
# - bce                     1    16576 16694
# - sec                     1    16576 16694
# - banking.system          1    16576 16694
# - real.economy            1    16577 16695
# - debt.jubilee            1    16578 16696
# - ethereum                1    16578 16696
# - fed                     1    16581 16699
# - blockchain              1    16582 16700
# - cryptonews              1    16584 16702
# - bitcoin.hack            1    16585 16703
# - bitcoin.bubble          1    16586 16704
# - vitalik.buterin         1    16587 16705
# - bitcoin.twitter         1    16590 16708
# - bitcoin.whales          1    16596 16714
# - microsoft               1    16596 16714
# - amazon                  1    16598 16716
# - bitcoin.dump            1    16602 16720
# - ray.dalio               1    16604 16722
# - bitcoin                 1    16615 16733
# - bitcoin.alert           1    16634 16752
#
# Step:  AIC=16685.6
# y ~ altcoins.season + banking.system + bce + bill.gates + bitcoin.alert +
#     bitcoin.bubble + bitcoin.dump + bitcoin.hack + bitcoin.pump +
#     bitcoin.whales + bitcoin + blockchain + coindesk + coingecko +
#     coinmarketcap + cointelegraph + crypto.assets + cryptonews +
#     debt.jubilee + debt + derivatives.market + dollar + economic.collapse +
#     economic.stimulus + financial.bubble + financial.independence +
#     housing.market + jamie.dimon + jerome.powell + microsoft +
#     money.printing + ray.dalio + real.economy + real.estate +
#     repo.market + satoshi.nakamoto + stimulus.bill + stocks.bubble +
#     stocks.crash + vitalik.buterin + volatility + warren.buffett +
#     wonder.woman + amazon + apple + bitcoin.twitter + ethereum +
#     smart.contracts + twitter + litecoin + ripple + netflix +
#     sec + investing + bloomberg + china.economy + facebook +
#     fed
#
#                          Df Deviance   AIC
# - stocks.bubble           1    16568 16684
# - money.printing          1    16568 16684
# - china.economy           1    16568 16684
# - coinmarketcap           1    16568 16684
# - repo.market             1    16568 16684
# - litecoin                1    16568 16684
# - warren.buffett          1    16568 16684
# - wonder.woman            1    16568 16684
# - stocks.crash            1    16568 16684
# - jamie.dimon             1    16568 16684
# - cointelegraph           1    16568 16684
# - economic.collapse       1    16568 16684
# - financial.bubble        1    16568 16684
# - altcoins.season         1    16568 16684
# - coindesk                1    16569 16685
# - stimulus.bill           1    16569 16685
# - investing               1    16569 16685
# - twitter                 1    16569 16685
# - crypto.assets           1    16569 16685
# - dollar                  1    16569 16685
# - derivatives.market      1    16569 16685
# - apple                   1    16569 16685
# - bitcoin.pump            1    16570 16686
# <none>                         16568 16686
# - economic.stimulus       1    16570 16686
# - bloomberg               1    16570 16686
# - ripple                  1    16570 16686
# - debt                    1    16570 16686
# - netflix                 1    16570 16686
# - bill.gates              1    16571 16687
# - satoshi.nakamoto        1    16571 16687
# - financial.independence  1    16571 16687
# - real.estate             1    16571 16687
# - jerome.powell           1    16572 16688
# - smart.contracts         1    16572 16688
# - housing.market          1    16572 16688
# - coingecko               1    16572 16688
# - facebook                1    16573 16689
# - volatility              1    16575 16691
# - bce                     1    16576 16692
# - sec                     1    16576 16692
# - banking.system          1    16577 16693
# - debt.jubilee            1    16578 16694
# - real.economy            1    16578 16694
# - ethereum                1    16578 16694
# - fed                     1    16581 16697
# - blockchain              1    16582 16698
# - cryptonews              1    16584 16700
# - bitcoin.hack            1    16585 16701
# - bitcoin.bubble          1    16586 16702
# - vitalik.buterin         1    16587 16703
# - bitcoin.twitter         1    16590 16706
# - bitcoin.whales          1    16596 16712
# - microsoft               1    16597 16713
# - amazon                  1    16598 16714
# - bitcoin.dump            1    16602 16718
# - ray.dalio               1    16605 16721
# - bitcoin                 1    16615 16731
# - bitcoin.alert           1    16634 16750
#
# Step:  AIC=16683.61
# y ~ altcoins.season + banking.system + bce + bill.gates + bitcoin.alert +
#     bitcoin.bubble + bitcoin.dump + bitcoin.hack + bitcoin.pump +
#     bitcoin.whales + bitcoin + blockchain + coindesk + coingecko +
#     coinmarketcap + cointelegraph + crypto.assets + cryptonews +
#     debt.jubilee + debt + derivatives.market + dollar + economic.collapse +
#     economic.stimulus + financial.bubble + financial.independence +
#     housing.market + jamie.dimon + jerome.powell + microsoft +
#     money.printing + ray.dalio + real.economy + real.estate +
#     repo.market + satoshi.nakamoto + stimulus.bill + stocks.crash +
#     vitalik.buterin + volatility + warren.buffett + wonder.woman +
#     amazon + apple + bitcoin.twitter + ethereum + smart.contracts +
#     twitter + litecoin + ripple + netflix + sec + investing +
#     bloomberg + china.economy + facebook + fed
#
#                          Df Deviance   AIC
# - money.printing          1    16568 16682
# - china.economy           1    16568 16682
# - coinmarketcap           1    16568 16682
# - repo.market             1    16568 16682
# - litecoin                1    16568 16682
# - warren.buffett          1    16568 16682
# - wonder.woman            1    16568 16682
# - stocks.crash            1    16568 16682
# - jamie.dimon             1    16568 16682
# - cointelegraph           1    16568 16682
# - economic.collapse       1    16568 16682
# - financial.bubble        1    16568 16682
# - altcoins.season         1    16568 16682
# - coindesk                1    16569 16683
# - stimulus.bill           1    16569 16683
# - investing               1    16569 16683
# - twitter                 1    16569 16683
# - crypto.assets           1    16569 16683
# - dollar                  1    16569 16683
# - derivatives.market      1    16569 16683
# - apple                   1    16569 16683
# - bitcoin.pump            1    16570 16684
# <none>                         16568 16684
# - economic.stimulus       1    16570 16684
# - bloomberg               1    16570 16684
# - ripple                  1    16570 16684
# - debt                    1    16570 16684
# - netflix                 1    16570 16684
# - bill.gates              1    16571 16685
# - satoshi.nakamoto        1    16571 16685
# - financial.independence  1    16571 16685
# - real.estate             1    16571 16685
# - jerome.powell           1    16572 16686
# - smart.contracts         1    16572 16686
# - housing.market          1    16572 16686
# - coingecko               1    16572 16686
# - facebook                1    16573 16687
# - volatility              1    16575 16689
# - bce                     1    16576 16690
# - sec                     1    16576 16690
# - banking.system          1    16577 16691
# - debt.jubilee            1    16578 16692
# - real.economy            1    16578 16692
# - ethereum                1    16578 16692
# - fed                     1    16581 16695
# - blockchain              1    16582 16696
# - cryptonews              1    16584 16698
# - bitcoin.hack            1    16585 16699
# - bitcoin.bubble          1    16586 16700
# - vitalik.buterin         1    16587 16701
# - bitcoin.twitter         1    16590 16704
# - bitcoin.whales          1    16596 16710
# - microsoft               1    16597 16711
# - amazon                  1    16598 16712
# - bitcoin.dump            1    16602 16716
# - ray.dalio               1    16605 16719
# - bitcoin                 1    16615 16729
# - bitcoin.alert           1    16634 16748
# Step:  AIC=16681.63
# y ~ altcoins.season + banking.system + bce + bill.gates + bitcoin.alert +
#     bitcoin.bubble + bitcoin.dump + bitcoin.hack + bitcoin.pump +
#     bitcoin.whales + bitcoin + blockchain + coindesk + coingecko +
#     coinmarketcap + cointelegraph + crypto.assets + cryptonews +
#     debt.jubilee + debt + derivatives.market + dollar + economic.collapse +
#     economic.stimulus + financial.bubble + financial.independence +
#     housing.market + jamie.dimon + jerome.powell + microsoft +
#     ray.dalio + real.economy + real.estate + repo.market + satoshi.nakamoto +
#     stimulus.bill + stocks.crash + vitalik.buterin + volatility +
#     warren.buffett + wonder.woman + amazon + apple + bitcoin.twitter +
#     ethereum + smart.contracts + twitter + litecoin + ripple +
#     netflix + sec + investing + bloomberg + china.economy + facebook +
#     fed
#
#                          Df Deviance   AIC
# - china.economy           1    16568 16680
# - coinmarketcap           1    16568 16680
# - repo.market             1    16568 16680
# - litecoin                1    16568 16680
# - warren.buffett          1    16568 16680
# - wonder.woman            1    16568 16680
# - stocks.crash            1    16568 16680
# - jamie.dimon             1    16568 16680
# - cointelegraph           1    16568 16680
# - economic.collapse       1    16568 16680
# - financial.bubble        1    16568 16680
# - altcoins.season         1    16568 16680
# - coindesk                1    16569 16681
# - stimulus.bill           1    16569 16681
# - investing               1    16569 16681
# - twitter                 1    16569 16681
# - crypto.assets           1    16569 16681
# - dollar                  1    16569 16681
# - derivatives.market      1    16569 16681
# - apple                   1    16569 16681
# - bitcoin.pump            1    16570 16682
# <none>                         16568 16682
# - economic.stimulus       1    16570 16682
# - bloomberg               1    16570 16682
# - ripple                  1    16570 16682
# - debt                    1    16570 16682
# - netflix                 1    16570 16682
# - bill.gates              1    16571 16683
# - satoshi.nakamoto        1    16571 16683
# - financial.independence  1    16571 16683
# - real.estate             1    16572 16684
# - jerome.powell           1    16572 16684
# - smart.contracts         1    16572 16684
# - housing.market          1    16572 16684
# - coingecko               1    16572 16684
# - facebook                1    16573 16685
# - volatility              1    16575 16687
# - bce                     1    16576 16688
# - sec                     1    16576 16688
# - banking.system          1    16577 16689
# - debt.jubilee            1    16578 16690
# - real.economy            1    16578 16690
# - ethereum                1    16578 16690
# - fed                     1    16581 16693
# - blockchain              1    16582 16694
# - cryptonews              1    16584 16696
# - bitcoin.hack            1    16585 16697
# - bitcoin.bubble          1    16586 16698
# - vitalik.buterin         1    16587 16699
# - bitcoin.twitter         1    16591 16703
# - bitcoin.whales          1    16596 16708
# - microsoft               1    16597 16709
# - amazon                  1    16598 16710
# - bitcoin.dump            1    16602 16714
# - ray.dalio               1    16605 16717
# - bitcoin                 1    16615 16727
# - bitcoin.alert           1    16634 16746
#
# Step:  AIC=16679.67
# y ~ altcoins.season + banking.system + bce + bill.gates + bitcoin.alert +
#     bitcoin.bubble + bitcoin.dump + bitcoin.hack + bitcoin.pump +
#     bitcoin.whales + bitcoin + blockchain + coindesk + coingecko +
#     coinmarketcap + cointelegraph + crypto.assets + cryptonews +
#     debt.jubilee + debt + derivatives.market + dollar + economic.collapse +
#     economic.stimulus + financial.bubble + financial.independence +
#     housing.market + jamie.dimon + jerome.powell + microsoft +
#     ray.dalio + real.economy + real.estate + repo.market + satoshi.nakamoto +
#     stimulus.bill + stocks.crash + vitalik.buterin + volatility +
#     warren.buffett + wonder.woman + amazon + apple + bitcoin.twitter +
#     ethereum + smart.contracts + twitter + litecoin + ripple +
#     netflix + sec + investing + bloomberg + facebook + fed
#
#                          Df Deviance   AIC
# - coinmarketcap           1    16568 16678
# - repo.market             1    16568 16678
# - litecoin                1    16568 16678
# - warren.buffett          1    16568 16678
# - wonder.woman            1    16568 16678
# - stocks.crash            1    16568 16678
# - jamie.dimon             1    16568 16678
# - cointelegraph           1    16568 16678
# - economic.collapse       1    16568 16678
# - financial.bubble        1    16568 16678
# - altcoins.season         1    16568 16678
# - coindesk                1    16569 16679
# - stimulus.bill           1    16569 16679
# - investing               1    16569 16679
# - twitter                 1    16569 16679
# - crypto.assets           1    16569 16679
# - dollar                  1    16569 16679
# - derivatives.market      1    16569 16679
# - apple                   1    16570 16680
# - bitcoin.pump            1    16570 16680
# <none>                         16568 16680
# - economic.stimulus       1    16570 16680
# - ripple                  1    16570 16680
# - bloomberg               1    16570 16680
# - debt                    1    16570 16680
# - netflix                 1    16570 16680
# - bill.gates              1    16571 16681
# - satoshi.nakamoto        1    16571 16681
# - financial.independence  1    16571 16681
# - real.estate             1    16572 16682
# - jerome.powell           1    16572 16682
# - smart.contracts         1    16572 16682
# - housing.market          1    16572 16682
# - coingecko               1    16572 16682
# - facebook                1    16573 16683
# - volatility              1    16575 16685
# - bce                     1    16576 16686
# - sec                     1    16576 16686
# - banking.system          1    16577 16687
# - debt.jubilee            1    16578 16688
# - real.economy            1    16578 16688
# - ethereum                1    16579 16689
# - fed                     1    16581 16691
# - blockchain              1    16583 16693
# - cryptonews              1    16584 16694
# - bitcoin.hack            1    16585 16695
# - bitcoin.bubble          1    16586 16696
# - vitalik.buterin         1    16587 16697
# - bitcoin.twitter         1    16591 16701
# - bitcoin.whales          1    16596 16706
# - microsoft               1    16597 16707
# - amazon                  1    16598 16708
# - bitcoin.dump            1    16602 16712
# - ray.dalio               1    16605 16715
# - bitcoin                 1    16616 16726
# - bitcoin.alert           1    16634 16744
#
# Step:  AIC=16677.74
# y ~ altcoins.season + banking.system + bce + bill.gates + bitcoin.alert +
#     bitcoin.bubble + bitcoin.dump + bitcoin.hack + bitcoin.pump +
#     bitcoin.whales + bitcoin + blockchain + coindesk + coingecko +
#     cointelegraph + crypto.assets + cryptonews + debt.jubilee +
#     debt + derivatives.market + dollar + economic.collapse +
#     economic.stimulus + financial.bubble + financial.independence +
#     housing.market + jamie.dimon + jerome.powell + microsoft +
#     ray.dalio + real.economy + real.estate + repo.market + satoshi.nakamoto +
#     stimulus.bill + stocks.crash + vitalik.buterin + volatility +
#     warren.buffett + wonder.woman + amazon + apple + bitcoin.twitter +
#     ethereum + smart.contracts + twitter + litecoin + ripple +
#     netflix + sec + investing + bloomberg + facebook + fed
#
#                          Df Deviance   AIC
# - repo.market             1    16568 16676
# - litecoin                1    16568 16676
# - warren.buffett          1    16568 16676
# - wonder.woman            1    16568 16676
# - stocks.crash            1    16568 16676
# - jamie.dimon             1    16568 16676
# - cointelegraph           1    16568 16676
# - economic.collapse       1    16568 16676
# - financial.bubble        1    16568 16676
# - altcoins.season         1    16569 16677
# - coindesk                1    16569 16677
# - stimulus.bill           1    16569 16677
# - investing               1    16569 16677
# - twitter                 1    16569 16677
# - crypto.assets           1    16569 16677
# - dollar                  1    16569 16677
# - derivatives.market      1    16570 16678
# - apple                   1    16570 16678
# - bitcoin.pump            1    16570 16678
# <none>                         16568 16678
# - economic.stimulus       1    16570 16678
# - bloomberg               1    16570 16678
# - debt                    1    16570 16678
# - ripple                  1    16570 16678
# - netflix                 1    16570 16678
# - bill.gates              1    16571 16679
# - satoshi.nakamoto        1    16571 16679
# - financial.independence  1    16571 16679
# - real.estate             1    16572 16680
# - jerome.powell           1    16572 16680
# - smart.contracts         1    16572 16680
# - housing.market          1    16572 16680
# - facebook                1    16573 16681
# - volatility              1    16576 16684
# - coingecko               1    16576 16684
# - bce                     1    16576 16684
# - sec                     1    16576 16684
# - banking.system          1    16578 16686
# - real.economy            1    16578 16686
# - debt.jubilee            1    16578 16686
# - ethereum                1    16579 16687
# - fed                     1    16582 16690
# - blockchain              1    16583 16691
# - cryptonews              1    16584 16692
# - bitcoin.hack            1    16585 16693
# - bitcoin.bubble          1    16587 16695
# - vitalik.buterin         1    16587 16695
# - bitcoin.twitter         1    16591 16699
# - bitcoin.whales          1    16596 16704
# - microsoft               1    16597 16705
# - amazon                  1    16598 16706
# - bitcoin.dump            1    16602 16710
# - ray.dalio               1    16605 16713
# - bitcoin                 1    16617 16725
# - bitcoin.alert           1    16634 16742
# Step:  AIC=16675.83
# y ~ altcoins.season + banking.system + bce + bill.gates + bitcoin.alert +
#     bitcoin.bubble + bitcoin.dump + bitcoin.hack + bitcoin.pump +
#     bitcoin.whales + bitcoin + blockchain + coindesk + coingecko +
#     cointelegraph + crypto.assets + cryptonews + debt.jubilee +
#     debt + derivatives.market + dollar + economic.collapse +
#     economic.stimulus + financial.bubble + financial.independence +
#     housing.market + jamie.dimon + jerome.powell + microsoft +
#     ray.dalio + real.economy + real.estate + satoshi.nakamoto +
#     stimulus.bill + stocks.crash + vitalik.buterin + volatility +
#     warren.buffett + wonder.woman + amazon + apple + bitcoin.twitter +
#     ethereum + smart.contracts + twitter + litecoin + ripple +
#     netflix + sec + investing + bloomberg + facebook + fed
#
#                          Df Deviance   AIC
# - litecoin                1    16568 16674
# - warren.buffett          1    16568 16674
# - wonder.woman            1    16568 16674
# - stocks.crash            1    16568 16674
# - jamie.dimon             1    16568 16674
# - cointelegraph           1    16568 16674
# - economic.collapse       1    16568 16674
# - financial.bubble        1    16569 16675
# - altcoins.season         1    16569 16675
# - coindesk                1    16569 16675
# - stimulus.bill           1    16569 16675
# - investing               1    16569 16675
# - twitter                 1    16569 16675
# - crypto.assets           1    16569 16675
# - dollar                  1    16569 16675
# - apple                   1    16570 16676
# - derivatives.market      1    16570 16676
# - bitcoin.pump            1    16570 16676
# <none>                         16568 16676
# - economic.stimulus       1    16570 16676
# - bloomberg               1    16570 16676
# - debt                    1    16570 16676
# - netflix                 1    16570 16676
# - ripple                  1    16570 16676
# - bill.gates              1    16571 16677
# - satoshi.nakamoto        1    16571 16677
# - financial.independence  1    16572 16678
# - real.estate             1    16572 16678
# - smart.contracts         1    16572 16678
# - jerome.powell           1    16572 16678
# - housing.market          1    16572 16678
# - facebook                1    16573 16679
# - volatility              1    16576 16682
# - coingecko               1    16576 16682
# - bce                     1    16576 16682
# - sec                     1    16577 16683
# - real.economy            1    16578 16684
# - debt.jubilee            1    16578 16684
# - banking.system          1    16578 16684
# - ethereum                1    16579 16685
# - fed                     1    16582 16688
# - blockchain              1    16583 16689
# - cryptonews              1    16585 16691
# - bitcoin.hack            1    16585 16691
# - bitcoin.bubble          1    16587 16693
# - vitalik.buterin         1    16587 16693
# - bitcoin.twitter         1    16591 16697
# - bitcoin.whales          1    16596 16702
# - microsoft               1    16597 16703
# - amazon                  1    16598 16704
# - bitcoin.dump            1    16602 16708
# - ray.dalio               1    16605 16711
# - bitcoin                 1    16617 16723
# - bitcoin.alert           1    16635 16741
#
# Step:  AIC=16673.93
# y ~ altcoins.season + banking.system + bce + bill.gates + bitcoin.alert +
#     bitcoin.bubble + bitcoin.dump + bitcoin.hack + bitcoin.pump +
#     bitcoin.whales + bitcoin + blockchain + coindesk + coingecko +
#     cointelegraph + crypto.assets + cryptonews + debt.jubilee +
#     debt + derivatives.market + dollar + economic.collapse +
#     economic.stimulus + financial.bubble + financial.independence +
#     housing.market + jamie.dimon + jerome.powell + microsoft +
#     ray.dalio + real.economy + real.estate + satoshi.nakamoto +
#     stimulus.bill + stocks.crash + vitalik.buterin + volatility +
#     warren.buffett + wonder.woman + amazon + apple + bitcoin.twitter +
#     ethereum + smart.contracts + twitter + ripple + netflix +
#     sec + investing + bloomberg + facebook + fed
#
#                          Df Deviance   AIC
# - wonder.woman            1    16568 16672
# - warren.buffett          1    16568 16672
# - stocks.crash            1    16568 16672
# - jamie.dimon             1    16568 16672
# - cointelegraph           1    16568 16672
# - economic.collapse       1    16569 16673
# - financial.bubble        1    16569 16673
# - altcoins.season         1    16569 16673
# - coindesk                1    16569 16673
# - stimulus.bill           1    16569 16673
# - investing               1    16569 16673
# - twitter                 1    16569 16673
# - crypto.assets           1    16569 16673
# - dollar                  1    16569 16673
# - derivatives.market      1    16570 16674
# - bitcoin.pump            1    16570 16674
# - apple                   1    16570 16674
# <none>                         16568 16674
# - economic.stimulus       1    16570 16674
# - bloomberg               1    16570 16674
# - debt                    1    16570 16674
# - ripple                  1    16570 16674
# - netflix                 1    16570 16674
# - satoshi.nakamoto        1    16571 16675
# - bill.gates              1    16571 16675
# - financial.independence  1    16572 16676
# - real.estate             1    16572 16676
# - smart.contracts         1    16572 16676
# - jerome.powell           1    16572 16676
# - housing.market          1    16573 16677
# - facebook                1    16573 16677
# - volatility              1    16576 16680
# - bce                     1    16576 16680
# - coingecko               1    16577 16681
# - sec                     1    16577 16681
# - debt.jubilee            1    16578 16682
# - real.economy            1    16578 16682
# - banking.system          1    16578 16682
# - ethereum                1    16580 16684
# - fed                     1    16582 16686
# - blockchain              1    16583 16687
# - cryptonews              1    16585 16689
# - bitcoin.hack            1    16585 16689
# - bitcoin.bubble          1    16587 16691
# - vitalik.buterin         1    16587 16691
# - bitcoin.twitter         1    16591 16695
# - bitcoin.whales          1    16597 16701
# - microsoft               1    16597 16701
# - amazon                  1    16599 16703
# - bitcoin.dump            1    16602 16706
# - ray.dalio               1    16606 16710
# - bitcoin                 1    16620 16724
# - bitcoin.alert           1    16635 16739
#
# Step:  AIC=16672.08
# y ~ altcoins.season + banking.system + bce + bill.gates + bitcoin.alert +
#     bitcoin.bubble + bitcoin.dump + bitcoin.hack + bitcoin.pump +
#     bitcoin.whales + bitcoin + blockchain + coindesk + coingecko +
#     cointelegraph + crypto.assets + cryptonews + debt.jubilee +
#     debt + derivatives.market + dollar + economic.collapse +
#     economic.stimulus + financial.bubble + financial.independence +
#     housing.market + jamie.dimon + jerome.powell + microsoft +
#     ray.dalio + real.economy + real.estate + satoshi.nakamoto +
#     stimulus.bill + stocks.crash + vitalik.buterin + volatility +
#     warren.buffett + amazon + apple + bitcoin.twitter + ethereum +
#     smart.contracts + twitter + ripple + netflix + sec + investing +
#     bloomberg + facebook + fed
#
#                          Df Deviance   AIC
# - warren.buffett          1    16568 16670
# - stocks.crash            1    16568 16670
# - jamie.dimon             1    16568 16670
# - cointelegraph           1    16568 16670
# - economic.collapse       1    16569 16671
# - financial.bubble        1    16569 16671
# - altcoins.season         1    16569 16671
# - coindesk                1    16569 16671
# - stimulus.bill           1    16569 16671
# - investing               1    16569 16671
# - twitter                 1    16569 16671
# - dollar                  1    16570 16672
# - crypto.assets           1    16570 16672
# - derivatives.market      1    16570 16672
# - apple                   1    16570 16672
# - bitcoin.pump            1    16570 16672
# <none>                         16568 16672
# - bloomberg               1    16570 16672
# - economic.stimulus       1    16570 16672
# - netflix                 1    16570 16672
# - ripple                  1    16570 16672
# - debt                    1    16570 16672
# - bill.gates              1    16571 16673
# - satoshi.nakamoto        1    16572 16674
# - financial.independence  1    16572 16674
# - jerome.powell           1    16572 16674
# - real.estate             1    16572 16674
# - smart.contracts         1    16573 16675
# - housing.market          1    16573 16675
# - facebook                1    16573 16675
# - volatility              1    16576 16678
# - bce                     1    16577 16679
# - coingecko               1    16577 16679
# - sec                     1    16577 16679
# - real.economy            1    16578 16680
# - debt.jubilee            1    16578 16680
# - banking.system          1    16578 16680
# - ethereum                1    16581 16683
# - fed                     1    16582 16684
# - blockchain              1    16583 16685
# - cryptonews              1    16585 16687
# - bitcoin.hack            1    16585 16687
# - bitcoin.bubble          1    16587 16689
# - vitalik.buterin         1    16588 16690
# - bitcoin.twitter         1    16591 16693
# - bitcoin.whales          1    16597 16699
# - microsoft               1    16597 16699
# - amazon                  1    16599 16701
# - bitcoin.dump            1    16603 16705
# - ray.dalio               1    16606 16708
# - bitcoin                 1    16621 16723
# - bitcoin.alert           1    16635 16737
# Step:  AIC=16670.25
# y ~ altcoins.season + banking.system + bce + bill.gates + bitcoin.alert +
#     bitcoin.bubble + bitcoin.dump + bitcoin.hack + bitcoin.pump +
#     bitcoin.whales + bitcoin + blockchain + coindesk + coingecko +
#     cointelegraph + crypto.assets + cryptonews + debt.jubilee +
#     debt + derivatives.market + dollar + economic.collapse +
#     economic.stimulus + financial.bubble + financial.independence +
#     housing.market + jamie.dimon + jerome.powell + microsoft +
#     ray.dalio + real.economy + real.estate + satoshi.nakamoto +
#     stimulus.bill + stocks.crash + vitalik.buterin + volatility +
#     amazon + apple + bitcoin.twitter + ethereum + smart.contracts +
#     twitter + ripple + netflix + sec + investing + bloomberg +
#     facebook + fed
#
#                          Df Deviance   AIC
# - jamie.dimon             1    16568 16668
# - stocks.crash            1    16569 16669
# - cointelegraph           1    16569 16669
# - economic.collapse       1    16569 16669
# - financial.bubble        1    16569 16669
# - altcoins.season         1    16569 16669
# - coindesk                1    16569 16669
# - investing               1    16569 16669
# - stimulus.bill           1    16569 16669
# - dollar                  1    16570 16670
# - crypto.assets           1    16570 16670
# - twitter                 1    16570 16670
# - apple                   1    16570 16670
# - derivatives.market      1    16570 16670
# - bitcoin.pump            1    16570 16670
# <none>                         16568 16670
# - bloomberg               1    16570 16670
# - economic.stimulus       1    16570 16670
# - ripple                  1    16571 16671
# - netflix                 1    16571 16671
# - debt                    1    16571 16671
# - satoshi.nakamoto        1    16572 16672
# - bill.gates              1    16572 16672
# - financial.independence  1    16572 16672
# - real.estate             1    16573 16673
# - jerome.powell           1    16573 16673
# - smart.contracts         1    16573 16673
# - housing.market          1    16573 16673
# - facebook                1    16574 16674
# - volatility              1    16576 16676
# - coingecko               1    16577 16677
# - bce                     1    16577 16677
# - sec                     1    16577 16677
# - real.economy            1    16578 16678
# - debt.jubilee            1    16579 16679
# - banking.system          1    16579 16679
# - ethereum                1    16581 16681
# - fed                     1    16582 16682
# - blockchain              1    16583 16683
# - cryptonews              1    16585 16685
# - bitcoin.hack            1    16586 16686
# - bitcoin.bubble          1    16587 16687
# - vitalik.buterin         1    16588 16688
# - bitcoin.twitter         1    16591 16691
# - microsoft               1    16597 16697
# - bitcoin.whales          1    16597 16697
# - amazon                  1    16599 16699
# - bitcoin.dump            1    16603 16703
# - ray.dalio               1    16606 16706
# - bitcoin                 1    16621 16721
# - bitcoin.alert           1    16636 16736
#
# Step:  AIC=16668.44
# y ~ altcoins.season + banking.system + bce + bill.gates + bitcoin.alert +
#     bitcoin.bubble + bitcoin.dump + bitcoin.hack + bitcoin.pump +
#     bitcoin.whales + bitcoin + blockchain + coindesk + coingecko +
#     cointelegraph + crypto.assets + cryptonews + debt.jubilee +
#     debt + derivatives.market + dollar + economic.collapse +
#     economic.stimulus + financial.bubble + financial.independence +
#     housing.market + jerome.powell + microsoft + ray.dalio +
#     real.economy + real.estate + satoshi.nakamoto + stimulus.bill +
#     stocks.crash + vitalik.buterin + volatility + amazon + apple +
#     bitcoin.twitter + ethereum + smart.contracts + twitter +
#     ripple + netflix + sec + investing + bloomberg + facebook +
#     fed
#
#                          Df Deviance   AIC
# - stocks.crash            1    16569 16667
# - cointelegraph           1    16569 16667
# - economic.collapse       1    16569 16667
# - financial.bubble        1    16569 16667
# - altcoins.season         1    16569 16667
# - investing               1    16569 16667
# - coindesk                1    16569 16667
# - stimulus.bill           1    16570 16668
# - dollar                  1    16570 16668
# - crypto.assets           1    16570 16668
# - twitter                 1    16570 16668
# - derivatives.market      1    16570 16668
# - bitcoin.pump            1    16570 16668
# <none>                         16568 16668
# - apple                   1    16571 16669
# - economic.stimulus       1    16571 16669
# - bloomberg               1    16571 16669
# - ripple                  1    16571 16669
# - debt                    1    16571 16669
# - netflix                 1    16571 16669
# - satoshi.nakamoto        1    16572 16670
# - financial.independence  1    16572 16670
# - bill.gates              1    16572 16670
# - real.estate             1    16573 16671
# - jerome.powell           1    16573 16671
# - smart.contracts         1    16573 16671
# - housing.market          1    16573 16671
# - facebook                1    16574 16672
# - volatility              1    16576 16674
# - coingecko               1    16577 16675
# - bce                     1    16577 16675
# - sec                     1    16577 16675
# - real.economy            1    16578 16676
# - debt.jubilee            1    16579 16677
# - banking.system          1    16579 16677
# - ethereum                1    16581 16679
# - fed                     1    16583 16681
# - blockchain              1    16583 16681
# - cryptonews              1    16585 16683
# - bitcoin.hack            1    16586 16684
# - bitcoin.bubble          1    16588 16686
# - vitalik.buterin         1    16588 16686
# - bitcoin.twitter         1    16591 16689
# - microsoft               1    16597 16695
# - bitcoin.whales          1    16597 16695
# - amazon                  1    16599 16697
# - bitcoin.dump            1    16603 16701
# - ray.dalio               1    16606 16704
# - bitcoin                 1    16622 16720
# - bitcoin.alert           1    16636 16734
#
# Step:  AIC=16666.67
# y ~ altcoins.season + banking.system + bce + bill.gates + bitcoin.alert +
#     bitcoin.bubble + bitcoin.dump + bitcoin.hack + bitcoin.pump +
#     bitcoin.whales + bitcoin + blockchain + coindesk + coingecko +
#     cointelegraph + crypto.assets + cryptonews + debt.jubilee +
#     debt + derivatives.market + dollar + economic.collapse +
#     economic.stimulus + financial.bubble + financial.independence +
#     housing.market + jerome.powell + microsoft + ray.dalio +
#     real.economy + real.estate + satoshi.nakamoto + stimulus.bill +
#     vitalik.buterin + volatility + amazon + apple + bitcoin.twitter +
#     ethereum + smart.contracts + twitter + ripple + netflix +
#     sec + investing + bloomberg + facebook + fed
#
#                          Df Deviance   AIC
# - cointelegraph           1    16569 16665
# - economic.collapse       1    16569 16665
# - financial.bubble        1    16569 16665
# - altcoins.season         1    16569 16665
# - coindesk                1    16570 16666
# - investing               1    16570 16666
# - stimulus.bill           1    16570 16666
# - twitter                 1    16570 16666
# - dollar                  1    16570 16666
# - crypto.assets           1    16570 16666
# - derivatives.market      1    16571 16667
# - bitcoin.pump            1    16571 16667
# - apple                   1    16571 16667
# <none>                         16569 16667
# - ripple                  1    16571 16667
# - economic.stimulus       1    16571 16667
# - bloomberg               1    16571 16667
# - netflix                 1    16571 16667
# - debt                    1    16571 16667
# - satoshi.nakamoto        1    16572 16668
# - financial.independence  1    16573 16669
# - bill.gates              1    16573 16669
# - real.estate             1    16573 16669
# - jerome.powell           1    16573 16669
# - smart.contracts         1    16573 16669
# - housing.market          1    16573 16669
# - facebook                1    16574 16670
# - volatility              1    16577 16673
# - coingecko               1    16577 16673
# - bce                     1    16578 16674
# - sec                     1    16578 16674
# - real.economy            1    16579 16675
# - debt.jubilee            1    16579 16675
# - banking.system          1    16579 16675
# - ethereum                1    16581 16677
# - fed                     1    16583 16679
# - blockchain              1    16584 16680
# - cryptonews              1    16586 16682
# - bitcoin.hack            1    16586 16682
# - bitcoin.bubble          1    16588 16684
# - vitalik.buterin         1    16588 16684
# - bitcoin.twitter         1    16591 16687
# - microsoft               1    16597 16693
# - bitcoin.whales          1    16597 16693
# - amazon                  1    16599 16695
# - bitcoin.dump            1    16603 16699
# - ray.dalio               1    16606 16702
# - bitcoin                 1    16622 16718
# - bitcoin.alert           1    16636 16732
# Step:  AIC=16664.97
# y ~ altcoins.season + banking.system + bce + bill.gates + bitcoin.alert +
#     bitcoin.bubble + bitcoin.dump + bitcoin.hack + bitcoin.pump +
#     bitcoin.whales + bitcoin + blockchain + coindesk + coingecko +
#     crypto.assets + cryptonews + debt.jubilee + debt + derivatives.market +
#     dollar + economic.collapse + economic.stimulus + financial.bubble +
#     financial.independence + housing.market + jerome.powell +
#     microsoft + ray.dalio + real.economy + real.estate + satoshi.nakamoto +
#     stimulus.bill + vitalik.buterin + volatility + amazon + apple +
#     bitcoin.twitter + ethereum + smart.contracts + twitter +
#     ripple + netflix + sec + investing + bloomberg + facebook +
#     fed
#
#                          Df Deviance   AIC
# - economic.collapse       1    16570 16664
# - financial.bubble        1    16570 16664
# - altcoins.season         1    16570 16664
# - investing               1    16570 16664
# - stimulus.bill           1    16570 16664
# - twitter                 1    16570 16664
# - crypto.assets           1    16570 16664
# - dollar                  1    16570 16664
# - coindesk                1    16570 16664
# - derivatives.market      1    16571 16665
# - apple                   1    16571 16665
# - bitcoin.pump            1    16571 16665
# <none>                         16569 16665
# - economic.stimulus       1    16571 16665
# - bloomberg               1    16571 16665
# - ripple                  1    16571 16665
# - netflix                 1    16572 16666
# - debt                    1    16572 16666
# - satoshi.nakamoto        1    16573 16667
# - financial.independence  1    16573 16667
# - bill.gates              1    16573 16667
# - real.estate             1    16573 16667
# - smart.contracts         1    16573 16667
# - jerome.powell           1    16573 16667
# - housing.market          1    16574 16668
# - facebook                1    16575 16669
# - volatility              1    16577 16671
# - coingecko               1    16577 16671
# - sec                     1    16578 16672
# - bce                     1    16578 16672
# - real.economy            1    16579 16673
# ...
# <none>                         16578 16656
# - derivatives.market      1    16580 16656
# - debt                    1    16580 16656
# - real.estate             1    16580 16656
# - bill.gates              1    16581 16657
# - financial.independence  1    16581 16657
# - satoshi.nakamoto        1    16581 16657
# - apple                   1    16581 16657
# - smart.contracts         1    16582 16658
# - jerome.powell           1    16582 16658
# - housing.market          1    16584 16660
# - facebook                1    16585 16661
# - sec                     1    16586 16662
# - coingecko               1    16587 16663
# - bce                     1    16587 16663
# - volatility              1    16588 16664
# - debt.jubilee            1    16588 16664
# - real.economy            1    16588 16664
# - banking.system          1    16588 16664
# - ethereum                1    16590 16666
# - fed                     1    16592 16668
# - blockchain              1    16592 16668
# - bitcoin.hack            1    16596 16672
# - vitalik.buterin         1    16597 16673
# - cryptonews              1    16598 16674
# - bitcoin.bubble          1    16598 16674
# - microsoft               1    16604 16680
# - amazon                  1    16607 16683
# - bitcoin.whales          1    16607 16683
# - bitcoin.twitter         1    16610 16686
# - bitcoin.dump            1    16613 16689
# - ray.dalio               1    16617 16693
# - bitcoin                 1    16632 16708
# - bitcoin.alert           1    16645 16721
# Step:  AIC=16655.31
# y ~ banking.system + bce + bill.gates + bitcoin.alert + bitcoin.bubble +
#     bitcoin.dump + bitcoin.hack + bitcoin.pump + bitcoin.whales +
#     bitcoin + blockchain + coingecko + cryptonews + debt.jubilee +
#     debt + derivatives.market + economic.stimulus + financial.independence +
#     housing.market + jerome.powell + microsoft + ray.dalio +
#     real.economy + real.estate + satoshi.nakamoto + vitalik.buterin +
#     volatility + amazon + apple + bitcoin.twitter + ethereum +
#     smart.contracts + netflix + sec + bloomberg + facebook +
#     fed
#
#                          Df Deviance   AIC
# - bloomberg               1    16581 16655
# - netflix                 1    16581 16655
# - economic.stimulus       1    16581 16655
# <none>                         16579 16655
# - bitcoin.pump            1    16581 16655
# - debt                    1    16582 16656
# - derivatives.market      1    16582 16656
# - bill.gates              1    16582 16656
# - real.estate             1    16582 16656
# - satoshi.nakamoto        1    16583 16657
# - financial.independence  1    16583 16657
# - jerome.powell           1    16583 16657
# - apple                   1    16584 16658
# - smart.contracts         1    16584 16658
# - housing.market          1    16585 16659
# - facebook                1    16587 16661
# - sec                     1    16588 16662
# - volatility              1    16589 16663
# - bce                     1    16589 16663
# - coingecko               1    16590 16664
# - banking.system          1    16590 16664
# - debt.jubilee            1    16590 16664
# - real.economy            1    16590 16664
# - fed                     1    16593 16667
# - ethereum                1    16593 16667
# - blockchain              1    16594 16668
# - bitcoin.hack            1    16598 16672
# - vitalik.buterin         1    16598 16672
# - bitcoin.bubble          1    16599 16673
# - cryptonews              1    16601 16675
# - microsoft               1    16605 16679
# - bitcoin.whales          1    16609 16683
# - amazon                  1    16609 16683
# - bitcoin.twitter         1    16611 16685
# - bitcoin.dump            1    16615 16689
# - ray.dalio               1    16619 16693
# - bitcoin                 1    16634 16708
# - bitcoin.alert           1    16649 16723
#
# Step:  AIC=16655.1
# y ~ banking.system + bce + bill.gates + bitcoin.alert + bitcoin.bubble +
#     bitcoin.dump + bitcoin.hack + bitcoin.pump + bitcoin.whales +
#     bitcoin + blockchain + coingecko + cryptonews + debt.jubilee +
#     debt + derivatives.market + economic.stimulus + financial.independence +
#     housing.market + jerome.powell + microsoft + ray.dalio +
#     real.economy + real.estate + satoshi.nakamoto + vitalik.buterin +
#     volatility + amazon + apple + bitcoin.twitter + ethereum +
#     smart.contracts + netflix + sec + facebook + fed
#
#                          Df Deviance   AIC
# - economic.stimulus       1    16583 16655
# - netflix                 1    16583 16655
# - bitcoin.pump            1    16583 16655
# <none>                         16581 16655
# - derivatives.market      1    16583 16655
# - debt                    1    16584 16656
# - bill.gates              1    16584 16656
# - real.estate             1    16584 16656
# - financial.independence  1    16585 16657
# - satoshi.nakamoto        1    16585 16657
# - jerome.powell           1    16585 16657
# - apple                   1    16585 16657
# - smart.contracts         1    16586 16658
# - housing.market          1    16586 16658
# - facebook                1    16589 16661
# - sec                     1    16590 16662
# - volatility              1    16590 16662
# - banking.system          1    16591 16663
# - bce                     1    16591 16663
# - coingecko               1    16591 16663
# - debt.jubilee            1    16592 16664
# - real.economy            1    16592 16664
# - ethereum                1    16594 16666
# - fed                     1    16595 16667
# - blockchain              1    16598 16670
# - bitcoin.hack            1    16599 16671
# - vitalik.buterin         1    16600 16672
# - bitcoin.bubble          1    16601 16673
# - cryptonews              1    16603 16675
# - bitcoin.whales          1    16611 16683
# - microsoft               1    16613 16685
# - amazon                  1    16613 16685
# - bitcoin.twitter         1    16613 16685
# - bitcoin.dump            1    16616 16688
# - ray.dalio               1    16620 16692
# - bitcoin                 1    16637 16709
# - bitcoin.alert           1    16651 16723
#
# Step:  AIC=16655.05
# y ~ banking.system + bce + bill.gates + bitcoin.alert + bitcoin.bubble +
#     bitcoin.dump + bitcoin.hack + bitcoin.pump + bitcoin.whales +
#     bitcoin + blockchain + coingecko + cryptonews + debt.jubilee +
#     debt + derivatives.market + financial.independence + housing.market +
#     jerome.powell + microsoft + ray.dalio + real.economy + real.estate +
#     satoshi.nakamoto + vitalik.buterin + volatility + amazon +
#     apple + bitcoin.twitter + ethereum + smart.contracts + netflix +
#     sec + facebook + fed
#
#                          Df Deviance   AIC
# - derivatives.market      1    16585 16655
# - bitcoin.pump            1    16585 16655
# <none>                         16583 16655
# - netflix                 1    16585 16655
# - debt                    1    16586 16656
# - bill.gates              1    16586 16656
# - real.estate             1    16587 16657
# - financial.independence  1    16587 16657
# - satoshi.nakamoto        1    16587 16657
# - apple                   1    16587 16657
# - jerome.powell           1    16587 16657
# - smart.contracts         1    16588 16658
# - housing.market          1    16588 16658
# - facebook                1    16591 16661
# - sec                     1    16592 16662
# - volatility              1    16593 16663
# - coingecko               1    16593 16663
# - real.economy            1    16593 16663
# - bce                     1    16593 16663
# - debt.jubilee            1    16594 16664
# - banking.system          1    16594 16664
# - ethereum                1    16596 16666
# - fed                     1    16597 16667
# - blockchain              1    16600 16670
# - bitcoin.hack            1    16601 16671
# - vitalik.buterin         1    16602 16672
# - bitcoin.bubble          1    16603 16673
# - cryptonews              1    16605 16675
# - bitcoin.whales          1    16613 16683
# - microsoft               1    16615 16685
# - bitcoin.twitter         1    16615 16685
# - amazon                  1    16615 16685
# - bitcoin.dump            1    16618 16688
# - ray.dalio               1    16622 16692
# - bitcoin                 1    16638 16708
# - bitcoin.alert           1    16653 16723
#
# Step:  AIC=16655.01
# y ~ banking.system + bce + bill.gates + bitcoin.alert + bitcoin.bubble +
#     bitcoin.dump + bitcoin.hack + bitcoin.pump + bitcoin.whales +
#     bitcoin + blockchain + coingecko + cryptonews + debt.jubilee +
#     debt + financial.independence + housing.market + jerome.powell +
#     microsoft + ray.dalio + real.economy + real.estate + satoshi.nakamoto +
#     vitalik.buterin + volatility + amazon + apple + bitcoin.twitter +
#     ethereum + smart.contracts + netflix + sec + facebook + fed
#
#                          Df Deviance   AIC
# - netflix                 1    16587 16655
# <none>                         16585 16655
# - bitcoin.pump            1    16587 16655
# - debt                    1    16588 16656
# - bill.gates              1    16588 16656
# - satoshi.nakamoto        1    16589 16657
# - real.estate             1    16589 16657
# - financial.independence  1    16589 16657
# - apple                   1    16589 16657
# - jerome.powell           1    16589 16657
# - smart.contracts         1    16589 16657
# - housing.market          1    16590 16658
# - facebook                1    16593 16661
# - sec                     1    16594 16662
# - bce                     1    16595 16663
# - real.economy            1    16595 16663
# - coingecko               1    16595 16663
# - volatility              1    16595 16663
# - debt.jubilee            1    16596 16664
# - ethereum                1    16599 16667
# - fed                     1    16600 16668
# - blockchain              1    16601 16669
# - banking.system          1    16602 16670
# - bitcoin.hack            1    16603 16671
# - vitalik.buterin         1    16604 16672
# - bitcoin.bubble          1    16605 16673
# - cryptonews              1    16607 16675
# - bitcoin.whales          1    16615 16683
# - amazon                  1    16616 16684
# - microsoft               1    16616 16684
# - bitcoin.twitter         1    16617 16685
# - bitcoin.dump            1    16620 16688
# - ray.dalio               1    16623 16691
# - bitcoin                 1    16639 16707
# - bitcoin.alert           1    16655 16723
# Step:  AIC=16654.72
# y ~ banking.system + bce + bill.gates + bitcoin.alert + bitcoin.bubble +
#     bitcoin.dump + bitcoin.hack + bitcoin.pump + bitcoin.whales +
#     bitcoin + blockchain + coingecko + cryptonews + debt.jubilee +
#     debt + financial.independence + housing.market + jerome.powell +
#     microsoft + ray.dalio + real.economy + real.estate + satoshi.nakamoto +
#     vitalik.buterin + volatility + amazon + apple + bitcoin.twitter +
#     ethereum + smart.contracts + sec + facebook + fed
#
#                          Df Deviance   AIC
# - debt                    1    16589 16655
# <none>                         16587 16655
# - bitcoin.pump            1    16589 16655
# - bill.gates              1    16590 16656
# - apple                   1    16590 16656
# - satoshi.nakamoto        1    16590 16656
# - financial.independence  1    16591 16657
# - jerome.powell           1    16591 16657
# - housing.market          1    16591 16657
# - smart.contracts         1    16591 16657
# - facebook                1    16594 16660
# - sec                     1    16595 16661
# - volatility              1    16596 16662
# - real.economy            1    16596 16662
# - real.estate             1    16596 16662
# - coingecko               1    16597 16663
# - bce                     1    16597 16663
# - debt.jubilee            1    16597 16663
# - ethereum                1    16600 16666
# - fed                     1    16601 16667
# - banking.system          1    16602 16668
# - bitcoin.hack            1    16604 16670
# - blockchain              1    16604 16670
# - vitalik.buterin         1    16606 16672
# - bitcoin.bubble          1    16607 16673
# - cryptonews              1    16608 16674
# - bitcoin.whales          1    16617 16683
# - bitcoin.twitter         1    16619 16685
# - microsoft               1    16620 16686
# - amazon                  1    16620 16686
# - bitcoin.dump            1    16622 16688
# - ray.dalio               1    16625 16691
# - bitcoin                 1    16642 16708
# - bitcoin.alert           1    16657 16723
#
# Step:  AIC=16654.71
# y ~ banking.system + bce + bill.gates + bitcoin.alert + bitcoin.bubble +
#     bitcoin.dump + bitcoin.hack + bitcoin.pump + bitcoin.whales +
#     bitcoin + blockchain + coingecko + cryptonews + debt.jubilee +
#     financial.independence + housing.market + jerome.powell +
#     microsoft + ray.dalio + real.economy + real.estate + satoshi.nakamoto +
#     vitalik.buterin + volatility + amazon + apple + bitcoin.twitter +
#     ethereum + smart.contracts + sec + facebook + fed
#
#                          Df Deviance   AIC
# - bitcoin.pump            1    16591 16655
# <none>                         16589 16655
# - bill.gates              1    16592 16656
# - apple                   1    16592 16656
# - housing.market          1    16592 16656
# - satoshi.nakamoto        1    16592 16656
# - financial.independence  1    16593 16657
# - smart.contracts         1    16593 16657
# - jerome.powell           1    16593 16657
# - facebook                1    16597 16661
# - real.economy            1    16598 16662
# - sec                     1    16598 16662
# - coingecko               1    16599 16663
# - debt.jubilee            1    16599 16663
# - bce                     1    16599 16663
# - volatility              1    16600 16664
# - fed                     1    16601 16665
# - ethereum                1    16601 16665
# - real.estate             1    16605 16669
# - banking.system          1    16606 16670
# - blockchain              1    16606 16670
# - bitcoin.hack            1    16606 16670
# - vitalik.buterin         1    16608 16672
# - bitcoin.bubble          1    16609 16673
# - cryptonews              1    16610 16674
# - bitcoin.whales          1    16618 16682
# - microsoft               1    16620 16684
# - bitcoin.twitter         1    16620 16684
# - bitcoin.dump            1    16624 16688
# - amazon                  1    16626 16690
# - ray.dalio               1    16630 16694
# - bitcoin                 1    16646 16710
# - bitcoin.alert           1    16658 16722
#
# Step:  AIC=16654.7
# y ~ banking.system + bce + bill.gates + bitcoin.alert + bitcoin.bubble +
#     bitcoin.dump + bitcoin.hack + bitcoin.whales + bitcoin +
#     blockchain + coingecko + cryptonews + debt.jubilee + financial.independence +
#     housing.market + jerome.powell + microsoft + ray.dalio +
#     real.economy + real.estate + satoshi.nakamoto + vitalik.buterin +
#     volatility + amazon + apple + bitcoin.twitter + ethereum +
#     smart.contracts + sec + facebook + fed
#
#                          Df Deviance   AIC
# <none>                         16591 16655
# - bill.gates              1    16594 16656
# - apple                   1    16594 16656
# - housing.market          1    16595 16657
# - financial.independence  1    16595 16657
# - satoshi.nakamoto        1    16595 16657
# - jerome.powell           1    16595 16657
# - smart.contracts         1    16595 16657
# - facebook                1    16599 16661
# - sec                     1    16600 16662
# - real.economy            1    16600 16662
# - coingecko               1    16600 16662
# - debt.jubilee            1    16601 16663
# - bce                     1    16602 16664
# - volatility              1    16602 16664
# - fed                     1    16603 16665
# - ethereum                1    16603 16665
# - real.estate             1    16607 16669
# - banking.system          1    16608 16670
# - bitcoin.hack            1    16608 16670
# - blockchain              1    16609 16671
# - vitalik.buterin         1    16611 16673
# - bitcoin.bubble          1    16611 16673
# - cryptonews              1    16612 16674
# - bitcoin.whales          1    16621 16683
# - microsoft               1    16623 16685
# - bitcoin.twitter         1    16623 16685
# - amazon                  1    16628 16690
# - ray.dalio               1    16632 16694
# - bitcoin.dump            1    16636 16698
# - bitcoin                 1    16647 16709
# - bitcoin.alert           1    16662 16724

# %% [markdown]
# >**The best model using backward method is:**

# %%
summary(mod_back)
# Out:
# Call:
# glm(formula = y ~ banking.system + bce + bill.gates + bitcoin.alert +
#     bitcoin.bubble + bitcoin.dump + bitcoin.hack + bitcoin.whales +
#     bitcoin + blockchain + coingecko + cryptonews + debt.jubilee +
#     financial.independence + housing.market + jerome.powell +
#     microsoft + ray.dalio + real.economy + real.estate + satoshi.nakamoto +
#     vitalik.buterin + volatility + amazon + apple + bitcoin.twitter +
#     ethereum + smart.contracts + sec + facebook + fed, family = "binomial",
#     data = db_training)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.5912  -0.6290  -0.5134  -0.3998   2.6630
#
# Coefficients:
#                          Estimate Std. Error z value Pr(>|z|)
# (Intercept)            -2.2604713  0.2455442  -9.206  < 2e-16 ***
# banking.system         -0.0069627  0.0016713  -4.166 3.10e-05 ***
# bce                    -0.0047299  0.0014395  -3.286 0.001017 **
# bill.gates             -0.0019633  0.0010967  -1.790 0.073413 .
# bitcoin.alert           0.0083154  0.0009735   8.542  < 2e-16 ***
# bitcoin.bubble          0.0051742  0.0011332   4.566 4.97e-06 ***
# bitcoin.dump            0.0068843  0.0010112   6.808 9.90e-12 ***
# bitcoin.hack            0.0049591  0.0011762   4.216 2.48e-05 ***
# bitcoin.whales          0.0051793  0.0009261   5.593 2.23e-08 ***
# bitcoin                -0.0133630  0.0017707  -7.547 4.47e-14 ***
# blockchain              0.0091635  0.0021783   4.207 2.59e-05 ***
# coingecko              -0.0053636  0.0017299  -3.101 0.001932 **
# cryptonews              0.0050159  0.0010765   4.659 3.17e-06 ***
# debt.jubilee            0.0031917  0.0009807   3.254 0.001136 **
# financial.independence -0.0031951  0.0015987  -1.999 0.045651 *
# housing.market          0.0036883  0.0018851   1.957 0.050397 .
# jerome.powell          -0.0022599  0.0010770  -2.098 0.035870 *
# microsoft               0.0141697  0.0025292   5.602 2.11e-08 ***
# ray.dalio              -0.0074606  0.0011585  -6.440 1.20e-10 ***
# real.economy            0.0050189  0.0016217   3.095 0.001969 **
# real.estate            -0.0091572  0.0023114  -3.962 7.44e-05 ***
# satoshi.nakamoto        0.0023815  0.0011754   2.026 0.042744 *
# vitalik.buterin         0.0053542  0.0011907   4.497 6.90e-06 ***
# volatility             -0.0066994  0.0019824  -3.379 0.000726 ***
# amazon                 -0.0122438  0.0019733  -6.205 5.48e-10 ***
# apple                   0.0029769  0.0016356   1.820 0.068743 .
# bitcoin.twitter         0.0086400  0.0015258   5.662 1.49e-08 ***
# ethereum               -0.0058081  0.0016376  -3.547 0.000390 ***
# smart.contracts         0.0030950  0.0014605   2.119 0.034078 *
# sec                     0.0034325  0.0011315   3.034 0.002416 **
# facebook                0.0072806  0.0025261   2.882 0.003950 **
# fed                     0.0039885  0.0011376   3.506 0.000454 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 17418  on 19734  degrees of freedom
# Residual deviance: 16591  on 19703  degrees of freedom
# AIC: 16655
#
# Number of Fisher Scoring iterations: 4

# %%
# Variables weren't used
mod_back$anova
# Out:
#    Step                 Df Deviance     Resid. Df Resid. Dev AIC
# 1                       NA           NA 19673     16567.59   16691.59
# 2  - economy.recovery    1 0.0001417224 19674     16567.59   16689.59
# 3  - elon.musk           1 0.0002047545 19675     16567.60   16687.60
# 4  - financial.crisis    1 0.0010184209 19676     16567.60   16685.60
# 5  - stocks.bubble       1 0.0141269361 19677     16567.61   16683.61
# 6  - money.printing      1 0.0196725419 19678     16567.63   16681.63
# 7  - china.economy       1 0.0382779995 19679     16567.67   16679.67
# 8  - coinmarketcap       1 0.0744741474 19680     16567.74   16677.74
# 9  - repo.market         1 0.0876703428 19681     16567.83   16675.83
# 10 - litecoin            1 0.0964832724 19682     16567.93   16673.93
# 11 - wonder.woman        1 0.1510165930 19683     16568.08   16672.08
# 12 - warren.buffett      1 0.1750715624 19684     16568.25   16670.25
# 13 - jamie.dimon         1 0.1906481705 19685     16568.44   16668.44
# 14 - stocks.crash        1 0.2233399816 19686     16568.67   16666.67
# 15 - cointelegraph       1 0.3037054258 19687     16568.97   16664.97
# 16 - economic.collapse   1 0.4867993417 19688     16569.46   16663.46
# 17 - financial.bubble    1 0.6038738151 19689     16570.06   16662.06
# 18 - altcoins.season     1 0.7022157888 19690     16570.76   16660.76
# 19 - investing           1 0.9681521285 19691     16571.73   16659.73
# 20 - stimulus.bill       1 0.9742621756 19692     16572.71   16658.71
# 21 - dollar              1 1.2338068561 19693     16573.94   16657.94
# 22 - twitter             1 1.1534215074 19694     16575.09   16657.09
# 23 - coindesk            1 1.1238446309 19695     16576.22   16656.22
# 24 - crypto.assets       1 1.3948530510 19696     16577.61   16655.61
# 25 - ripple              1 1.6985054471 19697     16579.31   16655.31
# 26 - bloomberg           1 1.7920680896 19698     16581.10   16655.10
# 27 - economic.stimulus   1 1.9487539002 19699     16583.05   16655.05
# 28 - derivatives.market  1 1.9584313541 19700     16585.01   16655.01
# 29 - netflix             1 1.7139745204 19701     16586.72   16654.72
# 30 - debt                1 1.9849697302 19702     16588.71   16654.71
# 31 - bitcoin.pump        1 1.9937661492 19703     16590.70   16654.70

# %% [markdown]
# # Multicolinearity

# %%
# Checking Variance Inflation Factor (VIF)
vif_back <- vif(mod_back)
vif_back
# Out:
#         banking.system                    bce             bill.gates
#               2.389211               2.285063               1.322708
#          bitcoin.alert         bitcoin.bubble           bitcoin.dump
#               1.120910               1.375831               1.181584
#           bitcoin.hack         bitcoin.whales                bitcoin
#               1.160150               1.058598               2.271884
#             blockchain              coingecko             cryptonews
#               3.026796               1.745070               1.287343
#           debt.jubilee financial.independence         housing.market
#               1.100706               2.038918               3.761043
#          jerome.powell              microsoft              ray.dalio
#               1.249511               3.485638               1.354432
#           real.economy            real.estate       satoshi.nakamoto
#               2.214650               5.459604               1.223744
#        vitalik.buterin             volatility                 amazon
#               1.247095               2.986440               1.857479
#                  apple        bitcoin.twitter               ethereum
#               1.966357               2.161656               1.747675
#        smart.contracts                    sec               facebook
#               1.828166               1.287511               1.866465
#                    fed
#               1.936113

# %%
# Variable with a multicolineality problem, assuming VIF > 1.5 
vif_back <- as.data.frame(vif_back)
vars_corr <- vif_back %>% filter(vif_back > 1.5) %>% row.names()
sort(vars_corr)
# Out:
#  [1] "amazon"                 "apple"                  "banking.system"
#  [4] "bce"                    "bitcoin"                "bitcoin.twitter"
#  [7] "blockchain"             "coingecko"              "ethereum"
# [10] "facebook"               "fed"                    "financial.independence"
# [13] "housing.market"         "microsoft"              "real.economy"
# [16] "real.estate"            "smart.contracts"        "volatility"

# %% [markdown]
# >**Let's check the correlation among all variables with "big" VIF's**

# %%
db_vif <- subset(db_testing, select=c(vars_corr))
db_corr <- cor(db_vif)
corrplot(db_corr, tl.col="brown", tl.srt=45, sig=0.5)
# Out:
# Plot with title ""

# %%
corr_simple <- function(data=df,sig=0.5){
  #convert data to numeric in order to run correlations
  #convert to factor first to keep the integrity of the data - each value will become a number rather than turn into NA
  df_cor <- data %>% mutate_if(is.character, as.factor)
  df_cor <- df_cor %>% mutate_if(is.factor, as.numeric)  #run a correlation and drop the insignificant ones
  corr <- cor(df_cor)
  #prepare to drop duplicates and correlations of 1     
  corr[lower.tri(corr,diag=TRUE)] <- NA 
  #drop perfect correlations
  corr[corr == 1] <- NA   #turn into a 3-column table
  corr <- as.data.frame(as.table(corr))
  #remove the NA values from above 
  corr <- na.omit(corr)   #select significant values  
  corr <- subset(corr, abs(Freq) > sig) 
  #sort by highest correlation
  corr <- corr[order(-abs(corr$Freq)),]   #print table
  #print(corr)  #turn corr back into matrix in order to plot with corrplot
  #mtx_corr <- reshape2::acast(corr, Var1~Var2, value.var="Freq")
  
  #plot correlations visually
  #corrplot(mtx_corr, is.corr=FALSE, tl.col="black", na.label=" ")

  return(corr)
}

df_correlations <- corr_simple(db_vif, 0.55)
df_correlations$Var1 <- as.character(df_correlations$Var1)
df_correlations$Var2 <- as.character(df_correlations$Var2)
df_correlations
# Out:
#     Var1                   Var2         Freq
# 300 amazon                 facebook     0.6888570
# 169 housing.market         real.estate  0.6370244
# 150 financial.independence real.economy 0.6179947
# 171 real.economy           real.estate  0.5979702
# 188 microsoft              volatility   0.5795577
# 323 facebook               fed          0.5562698

# %% [markdown]
# >**For simplicity the interaction between variables will be taken whose correlation value is: |ro| > 0.5**

# %% [markdown]
# # Model selection

# %% [markdown]
# ## Binomial regression

# %%
# Full model
mod_full <- glm(y ~ ., data = db_training, family = "binomial")

# %%
# Backward method model
mod_back <- glm(y ~ banking.system + bce + bill.gates + bitcoin.alert + 
                    bitcoin.bubble + bitcoin.dump + bitcoin.hack + bitcoin.whales + 
                    bitcoin + blockchain + coingecko + cryptonews + debt.jubilee + 
                    financial.independence + housing.market + jerome.powell + 
                    microsoft + ray.dalio + real.economy + real.estate + satoshi.nakamoto + 
                    vitalik.buterin + volatility + amazon + apple + bitcoin.twitter + 
                    ethereum + smart.contracts + sec + facebook + fed,
                data = db_training, family = "binomial")

# %%
# Backward method model without variables with high VIF
mod_back_vif <- glm(y ~ banking.system + bce + bill.gates + bitcoin.alert + 
                        bitcoin.bubble + bitcoin.dump + bitcoin.hack + bitcoin.whales + 
                        bitcoin + blockchain + coingecko + cryptonews + debt.jubilee + 
                        jerome.powell + ray.dalio + satoshi.nakamoto + 
                        vitalik.buterin + apple + bitcoin.twitter + 
                        ethereum + smart.contracts + sec,
                    data = db_training, family = "binomial")

# %%
# Backward method model with the interaction of variables with high VIF
mod_back_vif_interaction <- glm(formula = y ~ banking.system + bce + bill.gates + bitcoin.alert + 
                        bitcoin.bubble + bitcoin.dump + bitcoin.hack + bitcoin.whales + 
                        bitcoin + blockchain + coingecko + cryptonews + debt.jubilee + 
                        jerome.powell + ray.dalio + satoshi.nakamoto + 
                        vitalik.buterin + apple + bitcoin.twitter + 
                        ethereum + smart.contracts + sec +
                        amazon + 
                        facebook + 
                        housing.market + 
                        real.estate + 
                        financial.independence +
                        real.economy + 
                        microsoft + 
                        volatility + 
                        fed +
                        amazon*facebook +
                        housing.market*real.estate + 
                        financial.independence*real.economy +
                        real.economy*real.estate +
                        microsoft*volatility +
                        facebook*fed, 
                        family = "binomial", data = db_training)

# %% [markdown]
# ## Binomial Generalized Linear Mixed Models

# %%
# Full model (mixed model)
mx_mod_full <- glmer(y ~ altcoins.season + banking.system  + bce + bill.gates + 
                       bitcoin.alert + bitcoin.bubble + bitcoin.dump + bitcoin.hack + 
                       bitcoin.pump + bitcoin.whales + bitcoin + blockchain +
                       coindesk + coingecko + coinmarketcap + cointelegraph +
                       crypto.assets + cryptonews + debt.jubilee + debt  +
                       derivatives.market +  dollar + economic.collapse + economic.stimulus + 
                       economy.recovery + elon.musk  + financial.bubble +  financial.independence +
                       housing.market + jamie.dimon + jerome.powell + microsoft +
                       money.printing + ray.dalio + real.economy + real.estate +
                       repo.market + satoshi.nakamoto + stimulus.bill + stocks.bubble +
                       stocks.crash + vitalik.buterin + volatility  + warren.buffett +
                       wonder.woman + amazon + apple + bitcoin.twitter +
                       ethereum + smart.contracts + twitter + litecoin +
                       ripple + netflix + sec + investing +
                       bloomberg + china.economy + facebook + fed +
                       financial.crisis + 
                       (1|day) + (1|hour), 
                 data = db_training_t, family = "binomial")

# %%
# Backward method model (mixed model)
mx_mod_back <- glmer(y ~ banking.system + bce + bill.gates + bitcoin.alert + 
                        bitcoin.bubble + bitcoin.dump + bitcoin.hack + bitcoin.whales + 
                        bitcoin + blockchain + coingecko + cryptonews + debt.jubilee + 
                        financial.independence + housing.market + jerome.powell + 
                        microsoft + ray.dalio + real.economy + real.estate + satoshi.nakamoto + 
                        vitalik.buterin + volatility + amazon + apple + bitcoin.twitter + 
                        ethereum + smart.contracts + sec + facebook + fed +
                        (1|day) + (1|hour),
                data = db_training_t, family = "binomial")

# %%
mx_mod_back_vif <- glmer(y ~ banking.system + bce + bill.gates + bitcoin.alert + 
                        bitcoin.bubble + bitcoin.dump + bitcoin.hack + bitcoin.whales + 
                        bitcoin + blockchain + coingecko + cryptonews + debt.jubilee + 
                        jerome.powell + ray.dalio + satoshi.nakamoto + 
                        vitalik.buterin + apple + bitcoin.twitter + 
                        ethereum + smart.contracts + sec +
                        (1|day) + (1|hour), 
                    data = db_training_t, family = "binomial")

# %%
    mx_mod_back_vif_interaction  <- glmer(formula = y ~ banking.system + bce + bill.gates + bitcoin.alert + 
                                            bitcoin.bubble + bitcoin.dump + bitcoin.hack + bitcoin.whales + 
                                            bitcoin + blockchain + coingecko + cryptonews + debt.jubilee + 
                                            jerome.powell + ray.dalio + satoshi.nakamoto + 
                                            vitalik.buterin + apple + bitcoin.twitter + 
                                            ethereum + smart.contracts + sec +
                                            amazon + 
                                            facebook + 
                                            housing.market + 
                                            real.estate + 
                                            financial.independence +
                                            real.economy + 
                                            microsoft + 
                                            volatility + 
                                            fed +
                                            amazon*facebook +
                                            housing.market*real.estate + 
                                            financial.independence*real.economy +
                                            real.economy*real.estate +
                                            microsoft*volatility +
                                            facebook*fed + 
                                            (1|day) + (1|hour), 
                                    data = db_training_t, family = "binomial")

# %% [markdown]
# # Model prediction

# %% [markdown]
# ## Binomial regression

# %%
test_mod_full <- predict(mod_full, db_testing, type="response")
auc_mod_full = roc(db_testing$y ~ test_mod_full, plot = TRUE, print.auc = TRUE)
# Out:
# Setting levels: control = 0, case = 1
# Setting direction: controls < cases
# plot without title

# %%
test_mod_back <- predict(mod_back, db_testing, type="response")
auc_mod_back = roc(db_testing$y ~ test_mod_back, plot = TRUE, print.auc = TRUE)
# Out:
# Setting levels: control = 0, case = 1
# Setting direction: controls < cases
# plot without title

# %%
test_mod_back_vif <- predict(mod_back_vif, db_testing, type="response")
auc_mod_back_vif = roc(db_testing$y ~ test_mod_back_vif, plot = TRUE, print.auc = TRUE)
# Out:
# Setting levels: control = 0, case = 1
# Setting direction: controls < cases
# plot without title

# %%
test_mod_back_vif_interaction <- predict(mod_back_vif_interaction, db_testing, type="response")
auc_mod_back_vif_interaction = roc(db_testing$y ~ test_mod_back_vif_interaction, plot = TRUE, print.auc = TRUE)
# Out:
# Setting levels: control = 0, case = 1
# Setting direction: controls < cases
# plot without title

# %% [markdown]
# ## Binomial Generalized Linear Mixed Models

# %%
test_mx_mod_full <- predict(mx_mod_full, db_testing_t, type="response")
auc_mx_mod_full = roc(db_testing_t$y ~ test_mx_mod_full, plot = TRUE, print.auc = TRUE)
# Out:
# Setting levels: control = 0, case = 1
# Setting direction: controls < cases
# plot without title

# %%
test_mx_mod_back <- predict(mx_mod_back, db_testing_t, type="response")
auc_mx_mod_back = roc(db_testing_t$y ~ test_mx_mod_back, plot = TRUE, print.auc = TRUE)
# Out:
# Setting levels: control = 0, case = 1
# Setting direction: controls < cases
# plot without title

# %%
test_mx_mod_back_vif <- predict(mx_mod_back_vif, db_testing_t, type="response")
auc_mx_mod_back_vif = roc(db_testing_t$y ~ test_mx_mod_back_vif, plot = TRUE, print.auc = TRUE)
# Out:
# Setting levels: control = 0, case = 1
# Setting direction: controls < cases
# plot without title

# %%
test_mx_mod_back_vif_interaction <- predict(mx_mod_back_vif_interaction, db_testing_t, type="response")
auc_mx_mod_back_vif_interaction = roc(db_testing_t$y ~ test_mx_mod_back_vif_interaction, plot = TRUE, print.auc = TRUE)
# Out:
# Setting levels: control = 0, case = 1
# Setting direction: controls < cases
# plot without title
